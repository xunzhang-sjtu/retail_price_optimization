# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.formula.api import ols

from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data/store.csv')

# %%
df.head()
# Out:
#      date  price  qty  sell_id  sell_cat      item  year   holiday  \
# 0  1/1/12  15.50   46     1070         0    BURGER  2012  New Year
# 1  1/1/12  12.73   22     2051         2    BURGER  2012  New Year
# 2  1/1/12  12.73   22     2051         2      COKE  2012  New Year
# 3  1/1/12  12.75   18     2052         2    BURGER  2012  New Year
# 4  1/1/12  12.75   18     2052         2  LEMONADE  2012  New Year
#
#    is_weekend  is_schoolbreak  avg_temperature  is_outdoor
# 0           1               0             24.8           0
# 1           1               0             24.8           0
# 2           1               0             24.8           0
# 3           1               0             24.8           0
# 4           1               0             24.8           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             10840 non-null  object
#  1   price            10840 non-null  float64
#  2   qty              10840 non-null  int64
#  3   sell_id          10840 non-null  int64
#  4   sell_cat         10840 non-null  int64
#  5   item             10840 non-null  object
#  6   year             10840 non-null  int64
#  7   holiday          840 non-null    object
#  8   is_weekend       10840 non-null  int64
#  9   is_schoolbreak   10840 non-null  int64
#  10  avg_temperature  10840 non-null  float64
#  11  is_outdoor       10840 non-null  int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 1016.4+ KB

# %%
df.describe(include="all")
# Out:
#           date         price           qty       sell_id      sell_cat  \
# count    10840  10840.000000  10840.000000  10840.000000  10840.000000
# unique    1348           NaN           NaN           NaN           NaN
# top     3/1/13           NaN           NaN           NaN           NaN
# freq        64           NaN           NaN           NaN           NaN
# mean       NaN     12.469232     39.928044   1929.375000      1.750000
# std        NaN      1.332332     20.937454    324.829137      0.661468
# min        NaN     10.120000      8.000000   1070.000000      0.000000
# 25%        NaN     11.480000     24.000000   2051.000000      2.000000
# 50%        NaN     12.460000     34.000000   2052.000000      2.000000
# 75%        NaN     12.850000     50.000000   2053.000000      2.000000
# max        NaN     16.500000    124.000000   2053.000000      2.000000
#
#           item          year         holiday    is_weekend  is_schoolbreak  \
# ...

# %%
# Transform item and holiday to cateogry
df['item'] = df['item'].astype('category')
df['holiday'] = df['holiday'].astype('category')

# %%
# Transform date feature to date type
df['date'] = pd.to_datetime(df["date"],format="%m/%d/%y")

# %% [markdown]
# ### Check nulls

# %%
df.isnull().sum()
# Out:
# date                   0
# price                  0
# qty                    0
# sell_id                0
# sell_cat               0
# item                   0
# year                   0
# holiday            10000
# is_weekend             0
# is_schoolbreak         0
# avg_temperature        0
# is_outdoor             0
# dtype: int64

# %% [markdown]
# There are nulls in holiday. This may mean a 0, but let´s see.

# %%
df['holiday'].value_counts()
# Out:
# Luner New Year          224
# National Day            168
# Qing Ming Festival       96
# Labor Day                96
# Dragon Boat Festivel     96
# New Year                 80
# Mid-Autumn Day           56
# WWII Celebration         24
# Name: holiday, dtype: int64

# %%
df[df['holiday'].isnull()]
# Out:
#             date  price  qty  sell_id  sell_cat      item  year holiday  \
# 24    2012-01-04  15.50   88     1070         0    BURGER  2012     NaN
# 25    2012-01-04  12.73   26     2051         2    BURGER  2012     NaN
# 26    2012-01-04  12.73   26     2051         2      COKE  2012     NaN
# 27    2012-01-04  12.75   24     2052         2    BURGER  2012     NaN
# 28    2012-01-04  12.75   24     2052         2  LEMONADE  2012     NaN
# ...          ...    ...  ...      ...       ...       ...   ...     ...
# 10835 2015-09-10  11.50   18     2052         2    BURGER  2015     NaN
# 10836 2015-09-10  11.50   18     2052         2  LEMONADE  2015     NaN
# 10837 2015-09-10  11.26   50     2053         2    BURGER  2015     NaN
# 10838 2015-09-10  11.26   50     2053         2      COKE  2015     NaN
# 10839 2015-09-10  11.26   50     2053         2    COFFEE  2015     NaN
#
#        is_weekend  is_schoolbreak  avg_temperature  is_outdoor
# ...

# %% [markdown]
# That´s it. We will label encode and create a binary is_holiday and see which one perfoms better because I think that some holidays are more asociated to go to a cafe than others.

# %%
# Replace NA
df['holiday'] = np.where(df['holiday'].isnull(),'No holiday',df['holiday'])

# %%
# binary features
df['is_holiday'] = np.where(df['holiday'] == "No holiday",0,1)

# %%
# label encoder
encoder = LabelEncoder()
df['holiday']  = encoder.fit_transform(df['holiday'] )

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True,linewidth=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# is_holiday seems to have a slightly better linear relationshio with qty and price so we will keep this.

# %%
df = df.drop('holiday',axis=1)

# %% [markdown]
# # EDA

# %%
df.groupby('item')['qty'].sum().plot(kind='bar',title='Sales by item')
# Out:
# <AxesSubplot:title={'center':'Sales by item'}, xlabel='item'>

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(df,x='price',hue="item",common_norm=False)
plt.title('Price Distribution')
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %%
plt.figure(figsize=(10,5))
sns.histplot(df,x='qty',hue='item')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(df,x='price',y='qty',hue='item')
plt.title('QTY and Price Relation')
# Out:
# Text(0.5, 1.0, 'QTY and Price Relation')

# %% [markdown]
# To simplify, I will optimize the burgures since they are the most sold item and the one with more spread quantity distribution.

# %%
bur = df[df['item'] == "BURGER"]

# %%
plt.figure(figsize=(10,5))
sns.histplot(bur,x='qty')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(bur,x='price',y='qty')
plt.title('QTY and Price Relation')
# Out:
# Text(0.5, 1.0, 'QTY and Price Relation')

# %% [markdown]
# This graphic shows that there are different burgers on sale, at least we should differenciate when the burguers are being sold in solitary or in a combo.

# %%
bur['sell_cat'].value_counts(normalize=True).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 25% of burgers are sold in solitary and 75% are sold in a combo.

# %%
bur_1 = bur[bur['sell_cat'] == 0]

plt.figure(figsize=(10,5))
plt.ylim(0,140)
plt.xlim(10,18)
sns.scatterplot(bur_1,x='price',y='qty')
plt.title('QTY and Price Relation Burgers 1 Unit')
# Out:
# Text(0.5, 1.0, 'QTY and Price Relation Burgers 1 Unit')

# %% [markdown]
# Except for some outliers that we will study later looks pretty good for a regression.

# %%
bur_2 = bur[bur['sell_cat'] == 2]

plt.figure(figsize=(10,5))
plt.ylim(0,140)
plt.xlim(10,18)
sns.scatterplot(bur_2,x='price',y='qty')
plt.title('QTY and Price Relation Burgers Combo')
# Out:
# Text(0.5, 1.0, 'QTY and Price Relation Burgers Combo')

# %% [markdown]
# Still having a lot of spreadnes so we are going to divide each combo.

# %%
bur_2['sell_id'].unique()
# Out:
# array([2051, 2052, 2053], dtype=int64)

# %%
bur_2_1 = bur_2[bur_2['sell_id'] == 2051]
bur_2_2 = bur_2[bur_2['sell_id'] == 2052]
bur_2_3 = bur_2[bur_2['sell_id'] == 2053]

# %%
fig, ax = plt.subplots(3, 1,sharey=True,sharex = True, figsize = (30, 15))

ax1 = sns.scatterplot(bur_2_1,x='price',y='qty',ax=ax[0])
ax1.set_title('2051')


ax1 = sns.scatterplot(bur_2_2,x='price',y='qty',ax=ax[1])
ax1.set_title('2052')


ax1 = sns.scatterplot(bur_2_3,x='price',y='qty',ax=ax[2])
ax1.set_title('2053')

plt.ylim(0,90)
plt.xlim(10,16)
# Out:
# (10.0, 16.0)

# %% [markdown]
# This is more easy to work with. It is clear that we have to split the combos.

# %%
plt.figure(figsize=(10,5))
sns.heatmap(bur.corr(),annot=True,linewidth=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This reveals some important information:
#
#     1.- Confirmas that there is a linear relationship between qty and price
#     2.- We should add is_weekend to the ols model because it affects the quantity sold
#     3.- Split the burgers per combo is a good idea

# %% [markdown]
# ### Model QTY BURGER 1 Unit

# %% [markdown]
# ### Outliers

# %%
def find_outliers(data):
    q1, q3 = np.percentile(data, [25, 75])

    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    return lower_bound,upper_bound

# %%
sns.boxplot(bur_1,x='price')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
low,up = find_outliers(bur_1['price'])

print("The outliers represent the",round((bur_1[bur_1['price'] < low].shape[0] / bur_1.shape[0])* 100,2),"%")
# Out:
# The outliers represent the 0.3 %

# %% [markdown]
# As they represent a really low % we will just drop them

# %%
# Drop outliers
bur_1 = bur_1.drop(bur_1[bur_1['price'] < low].index)

# %%
plt.figure(figsize=(10,5))
sns.histplot(bur_1,x='qty')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %%
# Feature to save elasticities of all burgers models
elasticities = {}

bur_1_model = ols(formula='qty ~ price ', data=bur_1).fit()
print(bur_1_model.summary())
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(bur_1_model, fig=fig)

elasticities['bur_1'] = bur_1_model.params[1]
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    qty   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     186.4
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           7.72e-40
# Time:                        00:12:59   Log-Likelihood:                -5607.0
# No. Observations:                1351   AIC:                         1.122e+04
# Df Residuals:                    1349   BIC:                         1.123e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    197.6832      8.521     23.199      0.000     180.967     214.400
# ...

# %% [markdown]
# ### Model QTY Burger 2.1

# %%
sns.boxplot(bur_2_1,x='price')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
low,up = find_outliers(bur_2_1['price'])

print("The outliers represent the",round((bur_2_1[bur_2_1['price'] > up].shape[0] / bur_2_1.shape[0])* 100,2),"%")
# Out:
# The outliers represent the 0.3 %

# %%
# Drop outliers
bur_2_1 = bur_2_1.drop(bur_2_1[bur_2_1['price'] > up].index)

# %%
plt.figure(figsize=(10,5))
sns.histplot(bur_2_1,x='qty')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(bur_2_1,x='qty')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %%
bur_2_1_model = ols(formula='qty ~ price ', data=bur_2_1).fit()
print(bur_2_1_model.summary())
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(bur_2_1_model, fig=fig)

elasticities['bur_2_1'] = bur_2_1_model.params[1]
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    qty   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.102
# Method:                 Least Squares   F-statistic:                     154.7
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           1.06e-33
# Time:                        00:13:01   Log-Likelihood:                -4238.2
# No. Observations:                1351   AIC:                             8480.
# Df Residuals:                    1349   BIC:                             8491.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     61.4611      2.611     23.539      0.000      56.339      66.583
# ...

# %% [markdown]
# ### Model QTY Burger 2.2

# %%
sns.boxplot(bur_2_2,x='price')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(bur_2_2,x='qty')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %% [markdown]
# Looks like we have some outliers in the qty

# %%
sns.boxplot(bur_2_2,x='qty')
# Out:
# <AxesSubplot:xlabel='qty'>

# %%
up
# Out:
# 15.405000000000001

# %%
low,up = find_outliers(bur_2_2['qty'])

print("The outliers represent the",round((bur_2_2[bur_2_2['qty'] > up].shape[0] / bur_2_2.shape[0])* 100,2),"%")
# Out:
# The outliers represent the 0.74 %

# %%
# Drop outliers
bur_2_2 = bur_2_2.drop(bur_2_2[(bur_2_2['qty'] > up) | (bur_2_2['qty'] < low) ].index)

# %%
bur_2_2_model = ols(formula='qty ~ price ', data=bur_2_2).fit()
print(bur_2_2_model.summary())
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(bur_2_2_model, fig=fig)

elasticities['bur_2_2'] = bur_2_2_model.params[1]
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    qty   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     245.0
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           7.75e-51
# Time:                        00:13:02   Log-Likelihood:                -3771.0
# No. Observations:                1341   AIC:                             7546.
# Df Residuals:                    1339   BIC:                             7556.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     46.5501      1.658     28.071      0.000      43.297      49.803
# ...

# %% [markdown]
# ### Model QTY Burger 2.3

# %%
sns.boxplot(bur_2_3,x='price')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(bur_2_3,x='qty')
plt.title('QTY Distribution')
# Out:
# Text(0.5, 1.0, 'QTY Distribution')

# %%
sns.boxplot(bur_2_3,x='qty')
# Out:
# <AxesSubplot:xlabel='qty'>

# %%
low,up = find_outliers(bur_2_3['qty'])

print("The outliers represent the",round((bur_2_3[bur_2_3['qty'] > up].shape[0] / bur_2_3.shape[0])* 100,2),"%")
# Out:
# The outliers represent the 0.3 %

# %%
# Drop outliers
bur_2_3 = bur_2_3.drop(bur_2_3[(bur_2_3['qty'] > up) | (bur_2_3['qty'] < low) ].index)

# %%
bur_2_3_model = ols(formula='qty ~ price ', data=bur_2_3).fit()
print(bur_2_3_model.summary())
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(bur_2_3_model, fig=fig)

elasticities['bur_2_3'] = bur_2_3_model.params[1]
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    qty   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.243
# Method:                 Least Squares   F-statistic:                     434.2
# Date:                Fri, 17 Feb 2023   Prob (F-statistic):           7.85e-84
# Time:                        00:13:03   Log-Likelihood:                -4831.3
# No. Observations:                1351   AIC:                             9667.
# Df Residuals:                    1349   BIC:                             9677.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    107.9942      2.985     36.180      0.000     102.139     113.850
# ...

# %% [markdown]
# So, now we have the price elasticity for all type of burgers

# %%
print(elasticities)
# Out:
# {'bur_1': -7.660057574525013, 'bur_2_1': -2.61895594889873, 'bur_2_2': -2.159446957527802, 'bur_2_3': -5.1890334895248404}

# %% [markdown]
# # Calculate Max Profit

# %%
# Get max and min price
max_price = bur_1['price'].max()
min_price = bur_1['price'].min()

print('Max price:',max_price,'Min price:', min_price)
# Out:
# Max price: 16.5 Min price: 14.0

# %%
bur_1['item'].value_counts()
# Out:
# BURGER      1351
# LEMONADE       0
# COKE           0
# COFFEE         0
# Name: item, dtype: int64

# %% [markdown]
# # Notas
#
#     1.- Rehacer EDA Empezando con el profile report
#     2.- Aplicar box cox transf y z-score norm a qty y price

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(bur_1)
profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-02-16 23:17:41.063687&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
